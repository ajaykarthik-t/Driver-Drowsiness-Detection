# %%
import os
import pathlib
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import shutil
import random
import tensorflow as tf
from tensorflow import keras
import tensorflow_hub as hub
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout, BatchNormalization, GlobalAveragePooling2D, Activation, GlobalMaxPool2D, BatchNormalization
from tensorflow.keras.optimizers import Adam, Nadam
from tensorflow.keras import Input, Model
from tensorflow.keras.utils import plot_model
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import splitfolders
# Out:
# WARNING:tensorflow:From C:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
# splits dataset it into three subfolders: train, val (validation), and test.

splitfolders.ratio(r"C:\Users\Ajay\Desktop\Inno_Projects\Driver-Drowsiness-Detection\Dataset", output="output",
    seed=1337, ratio=(.75, .2, .05), group_prefix=None, move=False)
# Out:
# Copying files: 288 files [00:02, 135.49 files/s]

# %%
data_dir = pathlib.Path('output/')
train_dir = 'output/train'
val_dir = 'output/val'
test_dir = 'output/test'

# %%
class_name = np.array(sorted([item.name for item in data_dir.glob("*")]))
print(class_name)
# Out:
# ['test' 'train' 'val']

# %%
for dirpath, dirnames, filenames in os.walk('output'):
  print(f"{len(dirnames)} folder and {len(filenames)} images in {dirpath}")
# Out:
# 3 folder and 0 images in output
# 2 folder and 0 images in output\test
# 0 folder and 9 images in output\test\Active Driver
# 0 folder and 6 images in output\test\Drowsiness
# 2 folder and 0 images in output\train
# 0 folder and 126 images in output\train\Active Driver
# 0 folder and 90 images in output\train\Drowsiness
# 2 folder and 0 images in output\val
# 0 folder and 33 images in output\val\Active Driver
# 0 folder and 24 images in output\val\Drowsiness

# %%
def view_random_image(target_dir, target_class):
    target_folder = target_dir + target_class
    random_image = random.sample(os.listdir(target_folder), 1)
    img = mpimg.imread(target_folder + "/" + random_image[0])
    plt.imshow(img)
    plt.title(target_class)
    plt.axis("off")
    
    print(f"Image Shape : {img.shape}")
    plt.show()

# %%
for i in range(1,2):
    img_n = view_random_image(target_dir='output/train/', target_class='Active Driver')
# Out:
# Image Shape : (100, 100)

# %%
for i in range(1,2):
    img_n = view_random_image(target_dir='output/train/', target_class='Drowsiness')
# Out:
# Image Shape : (80, 80)

# %%
# Sets the global random seed.
tf.random.set_seed(46)

# preprocess data
train_datagen = ImageDataGenerator(rescale=1/255.0,
                                   rotation_range=0.2,
                                   zoom_range=0.2,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   vertical_flip=True,
                                   horizontal_flip=True)
valid_datagen = ImageDataGenerator(rescale=1/255.0)
test_datagen = ImageDataGenerator(rescale=1/255.0)

# %%
train_data = train_datagen.flow_from_directory(train_dir,
                                               batch_size=64,
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               shuffle=True,
                                               seed=46)

valid_data = valid_datagen.flow_from_directory(val_dir,
                                               batch_size=64,
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               shuffle=False,
                                               seed=46)

test_data = test_datagen.flow_from_directory(test_dir,
                                               batch_size=64,
                                               target_size=(224, 224),
                                               class_mode='categorical',
                                               shuffle=False,
                                               seed=46)
# Out:
# Found 216 images belonging to 2 classes.
# Found 57 images belonging to 2 classes.
# Found 15 images belonging to 2 classes.

# %%
train_data.class_indices
# Out:
# {'Active Driver': 0, 'Drowsiness': 1}

# %%
train_y=train_data.classes
val_y=valid_data.classes
test_y=test_data.classes

# %%
print("train_y.shape: ", train_y.shape)
print("val_y.shape: ", val_y.shape)
print("test_y.shape: ", test_y.shape)
# Out:
# train_y.shape:  (216,)
# val_y.shape:  (57,)
# test_y.shape:  (15,)

# %%
base_model = tf.keras.applications.DenseNet121(input_shape=(224, 224, 3),
                                                        include_top=False,
                                                        weights='imagenet')
base_model.trainable = False
# Out:
# WARNING:tensorflow:From C:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.

# %%
global_average_layer = GlobalAveragePooling2D()
prediction_layer = Dense(2)
softmax = Activation('softmax')

inputs = Input(shape=(224, 224, 3))
x = base_model(inputs, training=False)
x = Dropout(0.25)(x)
x = global_average_layer(x)
outputs = prediction_layer(x)
outputs = softmax(outputs)

model = Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  densenet121 (Functional)    (None, 7, 7, 1024)        7037504
#
#  dropout (Dropout)           (None, 7, 7, 1024)        0
#
#  global_average_pooling2d (  (None, 1024)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 2)                 2050
#
#  activation (Activation)     (None, 2)                 0
#
# =================================================================
# Total params: 7039554 (26.85 MB)
# Trainable params: 2050 (8.01 KB)
# Non-trainable params: 7037504 (26.85 MB)
# _________________________________________________________________

# %%
plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.001),
              metrics=['accuracy'])

# train model
history = model.fit(train_data, epochs=20, validation_data=valid_data)
# Out:
# Epoch 1/20
# WARNING:tensorflow:From C:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 4/4 [==============================] - 22s 5s/step - loss: 0.3827 - accuracy: 0.9120 - val_loss: 0.3123 - val_accuracy: 0.8947
# Epoch 2/20
# 4/4 [==============================] - 14s 3s/step - loss: 0.2910 - accuracy: 0.9769 - val_loss: 0.2335 - val_accuracy: 0.9474
# Epoch 3/20
# 4/4 [==============================] - 14s 4s/step - loss: 0.2408 - accuracy: 0.9537 - val_loss: 0.1777 - val_accuracy: 0.9825
# Epoch 4/20
# 4/4 [==============================] - 14s 3s/step - loss: 0.1833 - accuracy: 0.9907 - val_loss: 0.1375 - val_accuracy: 0.9825
# Epoch 5/20
# 4/4 [==============================] - 14s 4s/step - loss: 0.1533 - accuracy: 0.9722 - val_loss: 0.1083 - val_accuracy: 1.0000
# Epoch 6/20
# 4/4 [==============================] - 14s 4s/step - loss: 0.1194 - accuracy: 0.9722 - val_loss: 0.0866 - val_accuracy: 1.0000
# Epoch 7/20
# 4/4 [==============================] - 14s 3s/step - loss: 0.1170 - accuracy: 0.9676 - val_loss: 0.0701 - val_accuracy: 1.0000
# Epoch 8/20
# 4/4 [==============================] - 14s 4s/step - loss: 0.0882 - accuracy: 0.9907 - val_loss: 0.0587 - val_accuracy: 1.0000
# Epoch 9/20
# 4/4 [==============================] - 15s 4s/step - loss: 0.0996 - accuracy: 0.9769 - val_loss: 0.0511 - val_accuracy: 1.0000
# Epoch 10/20
# 4/4 [==============================] - 14s 4s/step - loss: 0.0850 - accuracy: 0.9861 - val_loss: 0.0459 - val_accuracy: 1.0000
# Epoch 11/20
# 4/4 [==============================] - 14s 3s/step - loss: 0.0775 - accuracy: 0.9907 - val_loss: 0.0408 - val_accuracy: 1.0000
# Epoch 12/20
# 4/4 [==============================] - 14s 4s/step - loss: 0.0691 - accuracy: 0.9769 - val_loss: 0.0352 - val_accuracy: 1.0000
# Epoch 13/20
# 4/4 [==============================] - 14s 3s/step - loss: 0.0701 - accuracy: 0.9861 - val_loss: 0.0315 - val_accuracy: 1.0000
# Epoch 14/20
# 4/4 [==============================] - 14s 3s/step - loss: 0.0593 - accuracy: 0.9907 - val_loss: 0.0287 - val_accuracy: 1.0000
# Epoch 15/20
# 4/4 [==============================] - 17s 4s/step - loss: 0.0528 - accuracy: 0.9954 - val_loss: 0.0265 - val_accuracy: 1.0000
# Epoch 16/20
# 4/4 [==============================] - 16s 4s/step - loss: 0.0524 - accuracy: 0.9907 - val_loss: 0.0247 - val_accuracy: 1.0000
# Epoch 17/20
# 4/4 [==============================] - 15s 4s/step - loss: 0.0533 - accuracy: 0.9861 - val_loss: 0.0235 - val_accuracy: 1.0000
# Epoch 18/20
# 4/4 [==============================] - 15s 4s/step - loss: 0.0483 - accuracy: 0.9907 - val_loss: 0.0221 - val_accuracy: 1.0000
# Epoch 19/20
# 4/4 [==============================] - 15s 4s/step - loss: 0.0448 - accuracy: 0.9907 - val_loss: 0.0204 - val_accuracy: 1.0000
# Epoch 20/20
# 4/4 [==============================] - 15s 4s/step - loss: 0.0421 - accuracy: 0.9907 - val_loss: 0.0192 - val_accuracy: 1.0000

# %%
def plot_loss_curves(history):
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(loss))

  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title("Loss Curves")
  plt.xlabel("Epochs")
  plt.legend()

  plt.figure()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title("Accuracy Curves")
  plt.xlabel("Epochs")
  plt.legend()

# %%
val_pred = model.predict(valid_data)
val_pred = val_pred.argmax(axis=1)
print(classification_report(val_pred, val_y))
# Out:
# 1/1 [==============================] - 5s 5s/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        33
#            1       1.00      1.00      1.00        24
#
#     accuracy                           1.00        57
#    macro avg       1.00      1.00      1.00        57
# weighted avg       1.00      1.00      1.00        57

# %%
cfm_val = confusion_matrix(val_pred, val_y)
ax = sns.heatmap(cfm_val, annot=True, 
            cmap='Blues')

# Preparation for plotting confusion matrix
ax.set_title('Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

# Display the visualization of the Confusion Matrix.
plt.show()

# %%
test_pred = model.predict(test_data)
test_pred = test_pred.argmax(axis=1)
print(classification_report(test_pred, test_y))
# Out:
# 1/1 [==============================] - 1s 903ms/step
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         9
#            1       1.00      1.00      1.00         6
#
#     accuracy                           1.00        15
#    macro avg       1.00      1.00      1.00        15
# weighted avg       1.00      1.00      1.00        15

# %%
cfm_test = confusion_matrix(test_pred, test_y)
ax = sns.heatmap(cfm_test, annot=True, 
            cmap='Blues')

# Preparation for plotting confusion matrix
ax.set_title('Confusion Matrix with labels\n\n');
ax.set_xlabel('\nPredicted Values')
ax.set_ylabel('Actual Values ');

# Display the visualization of the Confusion Matrix.
plt.show()

# %%
model.save('my_model.keras')

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\ajay\anaconda3\envs\py310\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\ajay\anaconda3\envs\py310\lib\site-packages (from opencv-python) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
from keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np

# Load the trained model
model = load_model('my_model.keras')

# Load the image
image_path = r"C:\Users\ajayk\Desktop\InnoProjects\SRIT\Driver Drowsiness detection using deep learning\Dataset\Drowsiness\s0001_00157_0_0_0_0_0_01.png"
image = image.load_img(image_path, target_size=(224, 224))

# Preprocess the image
img = np.array(image)
img = img / 255.0
img = img.reshape(1, 224, 224, 3)

# Predict the label
label = model.predict(img)

# Determine the predicted class
class_names = ['Active Driver', 'Drowsiness']
predicted_class_index = np.argmax(label)
predicted_class = class_names[predicted_class_index]

# Print the predicted class
print("Predicted Class:", predicted_class)

# Display the image with the predicted label
plt.imshow(image)
plt.title(predicted_class)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[28], line 11
#       9 # Load the image
#      10 image_path = r"C:\Users\ajayk\Desktop\InnoProjects\SRIT\Driver Drowsiness detection using deep learning\Dataset\Drowsiness\s0001_00157_0_0_0_0_0_01.png"
# ---> 11 image = image.load_img(image_path, target_size=(224, 224))
#      13 # Preprocess the image
#      14 img = np.array(image)
#
# File ~\anaconda3\envs\py310\lib\site-packages\keras\src\utils\image_utils.py:422, in load_img(path, grayscale, color_mode, target_size, interpolation, keep_aspect_ratio)
#     420     if isinstance(path, pathlib.Path):
#     421         path = str(path.resolve())
# --> 422     with open(path, "rb") as f:
#     423         img = pil_image.open(io.BytesIO(f.read()))
#     424 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\ajayk\\Desktop\\InnoProjects\\SRIT\\Driver Drowsiness detection using deep learning\\Dataset\\Drowsiness\\s0001_00157_0_0_0_0_0_01.png'

# %%
import matplotlib.pyplot as plt
from keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np

# Load the trained model
model = load_model('my_model.keras')

# Load the image
image_path = r"C:\Users\ajayk\Desktop\InnoProjects\SRIT\Driver Drowsiness detection using deep learning\Dataset\Active Driver\s0001_02379_0_0_1_0_0_01.png"
image = image.load_img(image_path, target_size=(224, 224))

# Preprocess the image
img = np.array(image)
img = img / 255.0
img = img.reshape(1, 224, 224, 3)

# Predict the label
label = model.predict(img)

# Determine the predicted class
class_names = ['Active Driver', 'Drowsiness']
predicted_class_index = np.argmax(label)
predicted_class = class_names[predicted_class_index]

# Print the predicted class
print("Predicted Class:", predicted_class)

# Display the image with the predicted label
plt.imshow(image)
plt.title(predicted_class)
plt.axis('off')
plt.show()

# %%
import tkinter as tk
from tkinter import filedialog
from PIL import Image
from keras.models import load_model
from tensorflow.keras.preprocessing import image
import numpy as np
import matplotlib.pyplot as plt

# Function to classify an image
def classify_image():
    # Load the trained model
    model = load_model('my_model.keras')
    
    # Open a dialog box to select an image file
    file_path = filedialog.askopenfilename(
        title="Select an Image File",
        filetypes=[("Image Files", "*.png;*.jpg;*.jpeg")]
    )
    
    if not file_path:
        print("No file selected.")
        return

    # Load the selected image and ensure it's in RGB mode
    img = Image.open(file_path).convert("RGB")
    img = img.resize((224, 224))  # Resize the image to match model input size

    # Convert image to numpy array and preprocess
    img_array = np.array(img)
    img_array = img_array / 255.0  # Normalize pixel values
    img_array = img_array.reshape(1, 224, 224, 3)

    # Predict the label
    label = model.predict(img_array)

    # Determine the predicted class
    class_names = ['Active Driver', 'Drowsiness']
    predicted_class_index = np.argmax(label)
    predicted_class = class_names[predicted_class_index]

    # Display the image with the predicted label
    plt.imshow(img)
    plt.title(predicted_class)
    plt.axis('off')
    plt.show()

# Create a Tkinter window
root = tk.Tk()
root.title("Drowsiness Detection Classifier")

# Create a button to trigger image classification
classify_button = tk.Button(root, text="Classify Image", command=classify_image)
classify_button.pack(pady=10)

# Run the Tkinter event loop
root.mainloop()
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
import cv2
import numpy as np
from keras.models import load_model

# Load the trained model
model = load_model('my_model.keras')

# Define class-specific messages
class_messages = {
    0: "You are active.",
}

# Default message (if not active)
default_message = "Not Active"

# Function to preprocess the image for prediction
def preprocess_frame(frame):
    frame_resized = cv2.resize(frame, (224, 224))  # Resize to model input size
    frame_array = np.array(frame_resized, dtype="float32") / 255.0  # Normalize
    frame_array = np.expand_dims(frame_array, axis=0)  # Add batch dimension
    return frame_array

# Access the webcam
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not access the webcam.")
else:
    print("Press 'q' to quit the application.")

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("Failed to grab frame. Exiting...")
        break

    # Get frame dimensions
    height, width, _ = frame.shape

    # Increase the size of the ROI
    roi_size = int(min(width, height) * 0.4)  # Square size is now 40% of the smaller dimension (increase this percentage)
    center_x, center_y = width // 2, height // 2
    roi_x1 = center_x - roi_size // 2
    roi_y1 = center_y - roi_size // 2
    roi_x2 = center_x + roi_size // 2
    roi_y2 = center_y + roi_size // 2

    # Draw the ROI rectangle on the frame
    cv2.rectangle(frame, (roi_x1, roi_y1), (roi_x2, roi_y2), (0, 255, 0), 2)

    # Extract the ROI for detection
    roi = frame[roi_y1:roi_y2, roi_x1:roi_x2]

    # Convert ROI to grayscale for Haar Cascade detection
    gray_roi = cv2.cvtColor(roi, cv2.COLOR_BGR2GRAY)

    # Load Haar Cascade for eye detection
    eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

    # Detect eyes within the ROI
    eyes = eye_cascade.detectMultiScale(gray_roi, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    if len(eyes) == 0:
        # If no eyes are detected, display the default message ("Drowsy")
        cv2.putText(
            frame,
            default_message,  # Display "You are drowsy" message
            (10, 30),
            cv2.FONT_HERSHEY_SIMPLEX,
            1,
            (0, 0, 255),
            2
        )
    else:
        # Preprocess the ROI for classification
        preprocessed_roi = preprocess_frame(roi)

        # Debug: print shape of preprocessed ROI
        print("Preprocessed ROI shape:", preprocessed_roi.shape)

        # Predict the class (Active or Drowsy)
        predictions = model.predict(preprocessed_roi)
        predicted_class_index = np.argmax(predictions)

        # Set the message based on predicted class
        if predicted_class_index == 0:
            predicted_message = class_messages[0]  # Active
        else:
            predicted_message = default_message  # Drowsy

        # Display the result on the webcam feed
        cv2.putText(
            frame,
            predicted_message,
            (10, 30),
            cv2.FONT_HERSHEY_SIMPLEX,
            1,
            (0, 255, 0),
            2
        )

    # Show the webcam feed with ROI
    cv2.imshow("Drowsiness Detection", frame)

    # Press 'q' to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Press 'q' to quit the application.
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 [==============================] - 2s 2s/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 [==============================] - 0s 81ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 [==============================] - 0s 96ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 [==============================] - 0s 88ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 [==============================] - 0s 89ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 [==============================] - 0s 84ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 [==============================] - 0s 83ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 [==============================] - 0s 93ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 [==============================] - 0s 96ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 [==============================] - 0s 107ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 [==============================] - 0s 110ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 [==============================] - 0s 98ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 [==============================] - 0s 94ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 [==============================] - 0s 137ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 [==============================] - 0s 81ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 [==============================] - 0s 99ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 [==============================] - 0s 89ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 [==============================] - 0s 98ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 [==============================] - 0s 96ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 [==============================] - 0s 82ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 [==============================] - 0s 90ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 [==============================] - 0s 109ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 [==============================] - 0s 93ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 [==============================] - 0s 95ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 [==============================] - 0s 98ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 [==============================] - 0s 123ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 [==============================] - 0s 99ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 [==============================] - 0s 88ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 [==============================] - 0s 90ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 [==============================] - 0s 92ms/step
# Preprocessed ROI shape: (1, 224, 224, 3)
# 1/1 [==============================] - 0s 100ms/step

# %%
import cv2
import numpy as np
from keras.models import load_model
import threading
import time
import winsound

# Load the trained model
model = load_model('my_model.keras')

# Define class-specific messages
class_messages = {
    0: "You are active.",
}

# Default message (if not active)
default_message = "Not Active"

# Alarm control
alarm_event = threading.Event()

def beep_alarm():
    """Thread function to control the alarm sound"""
    while True:
        if alarm_event.is_set():
            winsound.Beep(1000, 500)  # 1000Hz beep for 500ms
            time.sleep(0.5)  # Interval between beeps
        else:
            time.sleep(0.1)  # Sleep briefly when not active

# Start the alarm thread
alarm_thread = threading.Thread(target=beep_alarm, daemon=True)
alarm_thread.start()

# Function to preprocess the image for prediction
def preprocess_frame(frame):
    frame_resized = cv2.resize(frame, (224, 224))  # Resize to model input size
    frame_array = np.array(frame_resized, dtype="float32") / 255.0  # Normalize
    frame_array = np.expand_dims(frame_array, axis=0)  # Add batch dimension
    return frame_array

# Access the webcam
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not access the webcam.")
else:
    print("Press 'q' to quit the application.")

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("Failed to grab frame. Exiting...")
        break

    # Get frame dimensions
    height, width, _ = frame.shape

    # Increase the size of the ROI
    roi_size = int(min(width, height) * 0.4)
    center_x, center_y = width // 2, height // 2
    roi_x1 = center_x - roi_size // 2
    roi_y1 = center_y - roi_size // 2
    roi_x2 = center_x + roi_size // 2
    roi_y2 = center_y + roi_size // 2

    # Draw the ROI rectangle on the frame
    cv2.rectangle(frame, (roi_x1, roi_y1), (roi_x2, roi_y2), (0, 255, 0), 2)

    # Extract the ROI for detection
    roi = frame[roi_y1:roi_y2, roi_x1:roi_x2]

    # Convert ROI to grayscale for Haar Cascade detection
    gray_roi = cv2.cvtColor(roi, cv2.COLOR_BGR2GRAY)

    # Load Haar Cascade for eye detection
    eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

    # Detect eyes within the ROI
    eyes = eye_cascade.detectMultiScale(gray_roi, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    if len(eyes) == 0:
        # If no eyes detected, show warning and activate alarm
        cv2.putText(
            frame,
            default_message,
            (10, 30),
            cv2.FONT_HERSHEY_SIMPLEX,
            1,
            (0, 0, 255),
            2
        )
        alarm_event.set()
    else:
        # Preprocess the ROI for classification
        preprocessed_roi = preprocess_frame(roi)

        # Predict the class (Active or Drowsy)
        predictions = model.predict(preprocessed_roi)
        predicted_class_index = np.argmax(predictions)

        # Set message and alarm state based on prediction
        if predicted_class_index == 0:
            predicted_message = class_messages[0]
            alarm_event.clear()
        else:
            predicted_message = default_message
            alarm_event.set()

        # Display the result on the webcam feed
        cv2.putText(
            frame,
            predicted_message,
            (10, 30),
            cv2.FONT_HERSHEY_SIMPLEX,
            1,
            (0, 255, 0) if predicted_class_index == 0 else (0, 0, 255),
            2
        )

    # Show the webcam feed with ROI
    cv2.imshow("Drowsiness Detection", frame)

    # Press 'q' to exit
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the webcam and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING:tensorflow:From C:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\Ajay\anaconda3\envs\py310\lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Press 'q' to quit the application.
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 115ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 126ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 108ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 113ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 99ms/step

# %%
import cv2
import numpy as np
from keras.models import load_model
import threading
import time
import winsound
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk

# Load the trained model
model = load_model('my_model.keras')

# Define class-specific messages
class_messages = {
    0: "Driver is Active.",
    1: "Warning: Drowsy Driver!",
}

# Default message (if not active)
default_message = "Driver Status: Unknown"

# Alarm control
alarm_event = threading.Event()

def beep_alarm():
    """Thread function to control the alarm sound"""
    while True:
        if alarm_event.is_set():
            winsound.Beep(1000, 500)  # 1000Hz beep for 500ms
            time.sleep(0.5)  # Interval between beeps
        else:
            time.sleep(0.1)  # Sleep briefly when not active

# Start the alarm thread
alarm_thread = threading.Thread(target=beep_alarm, daemon=True)
alarm_thread.start()

# Function to preprocess the image for prediction
def preprocess_frame(frame):
    frame_resized = cv2.resize(frame, (224, 224))  # Resize to model input size
    frame_array = np.array(frame_resized, dtype="float32") / 255.0  # Normalize
    frame_array = np.expand_dims(frame_array, axis=0)  # Add batch dimension
    return frame_array

# Initialize Tkinter window
root = tk.Tk()
root.title("Driver Drowsiness Detection")
root.geometry("800x600")

# Create a Label widget for displaying the frame
frame_label = tk.Label(root)
frame_label.pack(padx=20, pady=20)

# Create a Text widget to display the driver status message
status_label = tk.Label(root, text=default_message, font=("Helvetica", 18))
status_label.pack(padx=20, pady=10)

# Access the webcam
cap = cv2.VideoCapture(0)

if not cap.isOpened():
    print("Error: Could not access the webcam.")
else:
    print("Press 'q' to quit the application.")

def update_frame():
    ret, frame = cap.read()
    if not ret:
        print("Failed to grab frame. Exiting...")
        return

    # Get frame dimensions
    height, width, _ = frame.shape

    # Increase the size of the ROI
    roi_size = int(min(width, height) * 0.4)
    center_x, center_y = width // 2, height // 2
    roi_x1 = center_x - roi_size // 2
    roi_y1 = center_y - roi_size // 2
    roi_x2 = center_x + roi_size // 2
    roi_y2 = center_y + roi_size // 2

    # Draw the ROI rectangle on the frame
    cv2.rectangle(frame, (roi_x1, roi_y1), (roi_x2, roi_y2), (0, 255, 0), 2)

    # Extract the ROI for detection
    roi = frame[roi_y1:roi_y2, roi_x1:roi_x2]

    # Convert ROI to grayscale for Haar Cascade detection
    gray_roi = cv2.cvtColor(roi, cv2.COLOR_BGR2GRAY)

    # Load Haar Cascade for eye detection
    eye_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_eye.xml')

    # Detect eyes within the ROI
    eyes = eye_cascade.detectMultiScale(gray_roi, scaleFactor=1.1, minNeighbors=5, minSize=(30, 30))

    if len(eyes) == 0:
        # If no eyes detected, show warning and activate alarm
        predicted_message = "Warning: No Eyes Detected!"
        alarm_event.set()
    else:
        # Preprocess the ROI for classification
        preprocessed_roi = preprocess_frame(roi)

        # Predict the class (Active or Drowsy)
        predictions = model.predict(preprocessed_roi)
        predicted_class_index = np.argmax(predictions)

        # Set message and alarm state based on prediction
        if predicted_class_index == 0:
            predicted_message = class_messages[0]
            alarm_event.clear()
        else:
            predicted_message = class_messages[1]
            alarm_event.set()

    # Display the status message
    status_label.config(text=predicted_message)

    # Convert the frame to a format Tkinter can handle and update the image
    cv2_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    img = Image.fromarray(cv2_rgb)
    imgtk = ImageTk.PhotoImage(image=img)
    frame_label.imgtk = imgtk
    frame_label.configure(image=imgtk)

    # Call this function again after 20ms to update the frame
    root.after(20, update_frame)

# Start updating the frame
update_frame()

# Run the Tkinter event loop
root.mainloop()

# Release the webcam and close all OpenCV windows
cap.release()
cv2.destroyAllWindows()
# Out:
# Press 'q' to quit the application.
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 105ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 103ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 99ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 93ms/step
# 1/1 [==============================] - 0s 102ms/step
# 1/1 [==============================] - 0s 110ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 106ms/step
# 1/1 [==============================] - 0s 105ms/step
